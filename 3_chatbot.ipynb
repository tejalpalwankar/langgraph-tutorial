# %%
from dotenv import load_dotenv
from langgraph.constants import START

load_dotenv()

from typing_extensions import TypedDict, Annotated
from typing_extensions import TypedDict
from    langchain.chat_models import init_chat_model
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages

# %%
from langchain.chat_models import init_chat_model

# %%
llm = init_chat_model("google_genai:gemini-2.5-flash")

# %%
class State(TypedDict):
    messages: Annotated[list, add_messages]

def chatbot(state: State) -> State:
    return {"messages": [llm.invoke(state["messages"])]}

# %%
builder = StateGraph(State)
builder.add_node("chatbot_node",chatbot)

builder.add_edge(START, "chatbot_node")
builder.add_edge("chatbot_node",END)

graph = builder.compile()

# %%
message = {"role": "user", "content": "Who walked on the moon for the first time? Print only the name"}
# message = {"role": "user", "content": "What is the latest price of MSFT stock?"}
response = graph.invoke({"messages":[message]})

response["messages"]
# Out:
# [HumanMessage(content='Who walked on the moon for the first time? Print only the name', additional_kwargs={}, response_metadata={}, id='9c3ec573-a93c-4966-bf12-89e63076c452'),
#  AIMessage(content='Neil Armstrong', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019cae05-52bf-7172-b4d2-c4abb2910057-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 45, 'total_tokens': 60, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 43}})]

# %%
state = None
while True:
    in_message = input("You: ")
    if in_message.lower() in {"quit","exit"}:
        break
    if state is None:
        state: State = {
            "messages": [{"role": "user", "content": in_message}]
        }
    else:
        state["messages"].append({"role": "user", "content": in_message})

    state = graph.invoke(state)
    print("Bot:", state["messages"][-1].content)
# Out:
# Bot: It's tricky to definitively name *the* "best" badminton player, as it depends on whether you're asking about current form, historical achievements, or specific disciplines (men's singles, women's singles, doubles, mixed doubles).
#
# However, here's a breakdown of the top contenders:
#
# ### Currently (as of late 2023 / early 2024):
#
# **Men's Singles:**
#
# *   **Viktor Axelsen (Denmark):** Widely considered the most dominant men's singles player of the last few years. He's an Olympic gold medalist, multiple World Champion, and frequently holds the world #1 ranking. His power, consistency, and tactical awareness are exceptional.
# *   **Shi Yuqi (China), Kunlavut Vitidsarn (Thailand), Jonatan Christie (Indonesia), Anthony Ginting (Indonesia), Kodai Naraoka (Japan):** These players are all consistently ranked high, win major tournaments, and provide strong challenges to Axelsen. Kunlavut Vitidsarn is the reigning World Champion (2023).
#
# **Women's Singles:**
#
# *   **An Se-young (South Korea):** Has been incredibly dominant in the past year, winning numerous titles including the 2023 World Championships and frequently holding the world #1 ranking. Her speed, agility, and relentless attack are formidable.
# *   **Akane Yamaguchi (Japan), Chen Yufei (China), Tai Tzu-ying (Chinese Taipei), Carolina Marin (Spain):** These are all former or current top players, Olympic medalists, and World Champions who consistently challenge for titles.
#
# ### All-Time Legends:
#
# When talking about the "greatest of all time," a few names stand out:
#
# *   **Lin Dan (China):** Often referred to as "Super Dan," he is arguably the greatest men's singles player ever. He is the only player to have completed the "Super Grand Slam" (winning all nine major titles in badminton). He won two consecutive Olympic gold medals (2008, 2012) and five World Championship titles.
# *   **Lee Chong Wei (Malaysia):** Lin Dan's great rival. While he famously never won an Olympic or World Championship gold, his incredible talent, consistency, and longevity are undeniable. He spent a record 349 weeks as world #1 and won countless Super Series titles. Many consider him the most gifted player never to win an Olympic or World title.
# *   **Gao Ling (China):** A doubles specialist who is the most decorated Olympic badminton player with 4 medals (2 gold, 1 silver, 1 bronze).
# *   **Rudy Hartono (Indonesia):** Dominated men's singles in the 1970s, winning the prestigious All England Open a record eight times (seven consecutively).
#
# **In conclusion:**
#
# *   For **current dominance in men's singles**, **Viktor Axelsen** is the strongest contender.
# *   For **current dominance in women's singles**, **An Se-young** is the strongest contender.
# *   For the **greatest of all time**, **Lin Dan** is the most frequently cited due to his unparalleled collection of major titles.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 3
#       1 state = None
#       2 while True:
# ----> 3     in_message = input("You: ")
#       4     if in_message.lower() in {"quit","exit"}:
#       5         break
#
# File ~/Documents/langgraph-learning/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/Documents/langgraph-learning/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
